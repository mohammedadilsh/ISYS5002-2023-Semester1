# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

print(df)

# %%
df.head()
# Out:
#          Date  Sales Revenue  Cost of Goods Sold  Operating Expenses
# 0  2022-02-01           5000                3000                1000
# 1  2022-02-02           6000                3500                1200
# 2  2022-02-03           7000                4000                1500
# 3  2022-02-04           4500                2500                 800
# 4  2022-02-05           8000                5000                2000

# %%
df.tail()
# Out:
#           Date  Sales Revenue  Cost of Goods Sold  Operating Expenses
# 23  2022-02-24           8000                4500                2000
# 24  2022-02-25           9000                5500                2500
# 25  2022-02-26           7500                4200                2000
# 26  2022-02-27           6000                3500                1200
# 27  2022-02-28           7000                4000                1500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                28 non-null     object
#  1   Sales Revenue       28 non-null     int64
#  2   Cost of Goods Sold  28 non-null     int64
#  3   Operating Expenses  28 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.0+ KB

# %%
df_revenue = df["Sales Revenue"]
df_revenue

# %%
df.sort_values("Sales Revenue", ascending = True)

# %%
df_columns = df[["Date", "Sales Revenue"]]
df_columns

# %%
df_columns[df_columns['Sales Revenue'] > 7000]
df_columns.head()
# Out:
#          Date  Sales Revenue
# 0  2022-02-01           5000
# 1  2022-02-02           6000
# 2  2022-02-03           7000
# 3  2022-02-04           4500
# 4  2022-02-05           8000

# %%
df_sum = df_columns["Sales Revenue"].sum()
df_max = df_columns["Sales Revenue"].max()
df_min = df_columns["Sales Revenue"].min()
df_mean = df_columns["Sales Revenue"].mean()

print(f"Revenue sum is {df_sum}, max is {df_max}, mean is {df_mean}")
# Out:
# Revenue sum is 189500, max is 9000, mean is 6767.857142857143

# %%
import matplotlib.pyplot as plt

df.plot(x="Date", y='Sales Revenue', figsize=(10, 6))
plt.title("Sales Revenue For Feb 2022")
plt.xlabel("Date")
plt.ylabel('Sales Revenue')
plt.show()

# %%
df_columns.to_csv("sales_revenue_out.csv", index=False)

# %% [markdown]
# ## import paycalc module

# %%
import paycalc

# %%
help(paycalc)

# %% [markdown]
# ## call the relevant functions from the `paycalc` module to
# * get user input
# * calculate the pay
# * print the payslip

# %%
name, salary, sales, comm = paycalc.user_input()
# Out:
# Please enter name: Ram
# Please enter salary: 2000
# Please enter sales: 30000
# Please enter commission rate: 2

# %%
commR, taxR, payR = paycalc.calculate_pay(salary, sales, comm)

# %%
paycalc.print_payslip(name, salary, commR, taxR, payR)
# Out:
# === Payslip of Ram ===
# Salary:      2000
# Commission: 600.0
# Tax:             0
# Total pay:   2600.0

# %%
name, salary, sales, comm = paycalc.user_input()
commR, taxR, payR = paycalc.calculate_pay(salary, sales, comm)
paycalc.print_payslip(name, salary, commR, taxR, payR)
# Out:
# Please enter name: Radha
# Please enter salary: 30000
# Please enter sales: 40000
# Please enter commission rate: 2
#
# === Payslip of Radha ===
# Salary:     30000
# Commission: 800.0
# Tax:        2394.0
# Total pay:  28406.0
